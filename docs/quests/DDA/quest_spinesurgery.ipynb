# %% [markdown]
# <a href="https://colab.research.google.com/github/entangelk/study_data_analytics/blob/main/docs/quests/DDA/quest_spinesurgery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
sslist = pd.read_csv('SpineSurgeryList.csv')

# %%
sslist.columns
# Out:
# Index(['Unnamed: 0', '환자ID', 'Large Lymphocyte', 'Location of herniation',
#        'ODI', '가족력', '간질성폐질환', '고혈압여부', '과거수술횟수', '당뇨여부', '말초동맥질환여부', '빈혈여부',
#        '성별', '스테로이드치료', '신부전여부', '신장', '심혈관질환', '암발병여부', '연령', '우울증여부', '입원기간',
#        '입원일자', '종양진행여부', '직업', '체중', '퇴원일자', '헤모글로빈수치', '혈전합병증여부', '환자통증정도',
#        '흡연여부', '통증기간(월)', '수술기법', '수술시간', '수술실패여부', '수술일자', '재발여부', '혈액형',
#        '전방디스크높이(mm)', '후방디스크높이(mm)', '지방축적도', 'Instability', 'MF + ES',
#        'Modic change', 'PI', 'PT', 'Seg Angle(raw)', 'Vaccum disc', '골밀도',
#        '디스크단면적', '디스크위치', '척추이동척도', '척추전방위증'],
#       dtype='object')

# %%
sslist
# Out:
#       Unnamed: 0    환자ID  Large Lymphocyte  Location of herniation   ODI  가족력  \
# 0              0     1PT              22.8                       3  51.0  0.0
# 1              1     2PT              44.9                       4  26.0  0.0
# 2              2     3PT              53.0                       3   NaN  0.0
# 3              3     4PT              54.7                       4  18.0  0.0
# 4              4     5PT              53.8                       4   NaN  0.0
# ...          ...     ...               ...                     ...   ...  ...
# 1889        1889  1890PT              44.0                       1   NaN  0.0
# 1890        1890  1891PT              30.8                       2   NaN  0.0
# 1891        1891  1892PT              36.7                       3   NaN  0.0
# 1892        1892  1893PT              32.5                       2   NaN  0.0
# 1893        1893  1894PT              49.5                       2   NaN  0.0
#
# ...

# %%
sslist.describe(include='all')
# Out:
#          Unnamed: 0  환자ID  Large Lymphocyte  Location of herniation  \
# count   1894.000000  1894       1894.000000             1894.000000
# unique          NaN  1894               NaN                     NaN
# top             NaN   1PT               NaN                     NaN
# freq            NaN     1               NaN                     NaN
# mean     946.500000   NaN         39.270750                2.295671
# std      546.895023   NaN         13.675874                0.996143
# min        0.000000   NaN          0.000000                1.000000
# 25%      473.250000   NaN         30.700000                1.000000
# 50%      946.500000   NaN         40.200000                2.000000
# 75%     1419.750000   NaN         48.600000                3.000000
# max     1893.000000   NaN         89.000000                5.000000
#
#                ODI          가족력       간질성폐질환        고혈압여부       과거수술횟수  \
# count   462.000000  1843.000000  1894.000000  1894.000000  1894.000000
# ...

# %%
sslist['Large Lymphocyte'].unique()

# %%
sslist['Location of herniation'].unique()

# %%
sslist['ODI'].unique()

# %%
sslist['가족력'].unique()

# %%
sslist['과거수술횟수'].unique()

# %%
sslist['당뇨여부'].unique()

# %%
sslist['직업'].unique()

# %%
sslist['수술기법'].unique()

# %%
sslist['혈액형'].unique()
# Out:
# array(['RH+A', 'RH+B', 'RH+O', 'RH+AB'], dtype=object)

# %%
sslist['Modic change'].unique()
# Out:
# array([3, 0, 2, 1])

# %%
sslist['척추이동척도'].unique()
# Out:
# array(['Down', 'Up', 'Middle', 'Extremely down', 'Extremely up'],
#       dtype=object)
