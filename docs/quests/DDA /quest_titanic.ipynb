# %% [markdown]
# <a href="https://colab.research.google.com/github/entangelk/study_data_analytics/blob/main/docs/quests/DDA%20/quest_titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_titanic = pd.read_csv('TitanicFromDisaster_test.csv')

# %%
df_titanic
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df_titanic.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_titanic['PassengerId'].unique(),df_titanic['Pclass'].unique(),df_titanic['Name'].unique(),df_titanic['Sex'].unique(),df_titanic['Age'].unique(),df_titanic['SibSp'].unique(),df_titanic['Parch'].unique(),df_titanic['Ticket'].unique(),df_titanic['Fare'].unique(),df_titanic['Cabin'].unique(),df_titanic['Embarked'].unique()
# Out:
# (array([ 892,  893,  894,  895,  896,  897,  898,  899,  900,  901,  902,
#          903,  904,  905,  906,  907,  908,  909,  910,  911,  912,  913,
#          914,  915,  916,  917,  918,  919,  920,  921,  922,  923,  924,
#          925,  926,  927,  928,  929,  930,  931,  932,  933,  934,  935,
#          936,  937,  938,  939,  940,  941,  942,  943,  944,  945,  946,
#          947,  948,  949,  950,  951,  952,  953,  954,  955,  956,  957,
#          958,  959,  960,  961,  962,  963,  964,  965,  966,  967,  968,
#          969,  970,  971,  972,  973,  974,  975,  976,  977,  978,  979,
#          980,  981,  982,  983,  984,  985,  986,  987,  988,  989,  990,
#          991,  992,  993,  994,  995,  996,  997,  998,  999, 1000, 1001,
#         1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010, 1011, 1012,
#         1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020, 1021, 1022, 1023,
#         1024, 1025, 1026, 1027, 1028, 1029, 1030, 1031, 1032, 1033, 1034,
# ...

# %%
df_titanic.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200
