# %% [markdown]
# <a href="https://colab.research.google.com/github/entangelk/study_data_analytics/blob/main/docs/quests/EDAs/preprocessing_titanic_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 한글 폰트 설치 및 시각화

# %%
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 설치 후 colab의 경우 런타임메뉴에서 리스타트 세션 해줘야함
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %% [markdown]
# - 한글 폰트 설치가 끝났으면 리스타트 잊지말라구!

# %%
import matplotlib as mpl
mpl.rc('font', family='NanumBarunGothic') # 혹은 다른 설치한 Nanum 폰트 사용

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# %%
# 유니코드 마이너스 사용 설정
plt.rcParams['axes.unicode_minus'] = False

# %%
import numpy as np

# %% [markdown]
# ## 시작

# %%
get_data = pd.read_csv('TitanicFromDisaster_train.csv')
get_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 문제 1. Age 열에서 결측치를 평균 나이로 채우기

# %%
cal_age = get_data['Age']
cal_age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
cal_age.dropna(inplace=True)
cal_age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
mean = round(cal_age.mean())
mean
# Out:
# 30

# %%
get_data['Age'] = get_data['Age'].replace(np.nan,mean)
get_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### 문제 2. cabin 열에 결측치가 있는 행을 찾고, 해당 행들의 평균 Fare 계산하기

# %%
get_data['Cabin_isnull'] = get_data['Cabin'].isnull()
get_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
get_data.query('Cabin_isnull == True')['Fare'].mean()
# Out:
# 19.157325327510915

# %% [markdown]
# ### 문제 3. Embarked 열에서 결측치가 있는 행을 찾고, 가장 많이 등장하는 항구로 채우기

# %%
max_key = get_data['Embarked'].value_counts().index[0]
max_key
# Out:
# 'S'

# %%
get_data['Embarked'] = get_data['Embarked'].replace(np.nan,max_key)
get_data['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
get_data['Embarked'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### 문제 4. Fare 열에서 평균보다 3표준편차 이상 높은 이상치를 가진 행들을 찾기

# %%
fare_mean = get_data['Fare'].mean()
fare_std = get_data['Fare'].std()
get_data[get_data['Fare'] > fare_mean + fare_std*3]
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 258          259         1       1
# 299          300         1       1
# 311          312         1       1
# 341          342         1       1
# 377          378         0       1
# 380          381         1       1
# 438          439         0       1
# 527          528         0       1
# 557          558         0       1
# 679          680         1       1
# 689          690         1       1
# 700          701         1       1
# 716          717         1       1
# 730          731         1       1
# 737          738         1       1
# 742          743         1       1
# 779          780         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ...

# %% [markdown]
# ### 문제 5. SibSp (형제 자매/배우자수)가 5 이상인 이상치를 가진 행들을 찾기

# %%
get_data.query('SibSp >= 5')
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 59            60         0       3  Goodwin, Master. William Frederick
# 71            72         0       3          Goodwin, Miss. Lillian Amy
# 159          160         0       3          Sage, Master. Thomas Henry
# 180          181         0       3        Sage, Miss. Constance Gladys
# 201          202         0       3                 Sage, Mr. Frederick
# 324          325         0       3            Sage, Mr. George John Jr
# 386          387         0       3     Goodwin, Master. Sidney Leonard
# 480          481         0       3      Goodwin, Master. Harold Victor
# 683          684         0       3         Goodwin, Mr. Charles Edward
# 792          793         0       3             Sage, Miss. Stella Anna
# 846          847         0       3            Sage, Mr. Douglas Bullen
# 863          864         0       3   Sage, Miss. Dorothy Edith "Dolly"
#
# ...

# %% [markdown]
# ### 문제 6. Parch (부모/자녀 수) 열에서 0이 아닌 값을 가진 행들의 평균 Age 계산하기.

# %%
get_data.query('Parch != 0')['Age'].mean()
# Out:
# 23.662769953051644

# %% [markdown]
# ### 문제 7. Fare 가 0인 행들을 찾고, 이를 평균 Fare로 채우기

# %%
get_data.query('Fare == 0')
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
get_data['Fare'] = get_data['Fare'].replace(0.0,fare_mean)
get_data.query('Fare == 0')
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Cabin_isnull]
# Index: []

# %% [markdown]
# ### 문제 8. Pclass (티켓 등급)가 1등급인 승객들 중 Cabin 열의 결측치 비율 계산하기

# %%
count_total = get_data.query('Pclass == 1')['Cabin'].value_counts().sum()
count_total
# Out:
# 176

# %%
get_data.query('Pclass == 1')['Cabin'].unique()
# Out:
# array(['C85', 'C123', 'E46', 'C103', 'A6', 'C23 C25 C27', nan, 'B78',
#        'D33', 'B30', 'C52', 'B28', 'C83', 'E31', 'A5', 'D10 D12', 'D26',
#        'C110', 'B58 B60', 'D47', 'B86', 'C2', 'E33', 'B19', 'A7', 'C49',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'C22 C26', 'C106', 'C65', 'E36', 'C54', 'B57 B59 B63 B66',
#        'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40', 'T', 'C128',
#        'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E44', 'A34', 'C104',
#        'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14', 'B37', 'C30',
#        'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38', 'B39', 'B22',
#        'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68', 'B41', 'A20',
#        'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48', 'E58', 'C126',
#        'B71', 'B51 B53 B55', 'D49', 'B5', 'B20', 'C62 C64', 'E24', 'C90',
# ...

# %%
# count_nan = get_data.query(f'Pclass == 1 & Cabin == {np.nan}')['Cabin'].value_counts().sum()
count_nan = get_data.loc[(get_data['Pclass'] == 1) & (get_data['Cabin'].isnull())]['Pclass'].value_counts().sum()
count_nan
# Out:
# 40

# %%
answer = (count_nan / count_total)*100
answer
# Out:
# 22.727272727272727

# %% [markdown]
# ### 문제 9. Age와 Fare 모두에 결측치가 있는 행들 찾기

# %%
get_data_second = pd.read_csv('TitanicFromDisaster_train.csv')

# %%
get_data_second[get_data_second['Age'].isna()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
get_data_second[get_data_second['Fare']==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
# get_data_second.query(f'Age == {np.nan} & Fare == {np.nan}')
get_data_second[(get_data_second['Age'].isna()) & (get_data_second['Fare'] == 0)]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# 732          733         0       2              Knight, Mr. Robert J  male
# 815          816         0       1                  Fry, Mr. Richard  male
#
#      Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 277  NaN      0      0  239853   0.0   NaN        S
# 413  NaN      0      0  239853   0.0   NaN        S
# 466  NaN      0      0  239853   0.0   NaN        S
# 481  NaN      0      0  239854   0.0   NaN        S
# ...

# %% [markdown]
# ### 문제 10. Sex 열에서 값이 male 또는 female이 아닌 이상치를 가진 행들을 찾기

# %%
get_data.query('Sex != "male" & Sex != "female"')
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Cabin_isnull]
# Index: []

# %%
get_data['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# ### 문제 11. Fare 열의 결측치를 해당 Pclass의 평균 요금으로 채우기

# %%
get_data_second.query('Fare == 0')
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
class_1_mean = get_data_second[(get_data_second['Pclass'] == 1) & (get_data_second['Fare'] != 0)]['Fare'].mean()
class_2_mean = get_data_second[(get_data_second['Pclass'] == 2) & (get_data_second['Fare'] != 0)]['Fare'].mean()
class_3_mean = get_data_second[(get_data_second['Pclass'] == 3) & (get_data_second['Fare'] != 0)]['Fare'].mean()

# %%
get_data_second[(get_data_second['Pclass'] == 2)].query('Fare == 0')
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# 732          733         0       2              Knight, Mr. Robert J  male
#
#      Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 277  NaN      0      0  239853   0.0   NaN        S
# 413  NaN      0      0  239853   0.0   NaN        S
# 466  NaN      0      0  239853   0.0   NaN        S
# 481  NaN      0      0  239854   0.0   NaN        S
# 674  NaN      0      0  239856   0.0   NaN        S
# 732  NaN      0      0  239855   0.0   NaN        S

# %%
# get_data_second[(get_data_second['Pclass'] == 1)]['Fare'].replace(0.0,class_1_mean)
get_data_second.loc[(get_data_second['Pclass'] == 1) & (get_data_second['Fare'] == 0), 'Fare'] = class_1_mean

# %%
# get_data_second[(get_data_second['Pclass'] == 2)]['Fare'].replace(0.0,class_2_mean)
# get_data_second[(get_data_second['Pclass'] == 3)]['Fare'].replace(0.0,class_3_mean)
get_data_second.loc[(get_data_second['Pclass'] == 2) & (get_data_second['Fare'] == 0), 'Fare'] = class_2_mean
get_data_second.loc[(get_data_second['Pclass'] == 3) & (get_data_second['Fare'] == 0), 'Fare'] = class_3_mean

# %%
get_data_second.query('Fare == 0')
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []
