# %% [markdown]
# <a href="https://colab.research.google.com/github/entangelk/study_data_analytics/blob/main/docs/pandas/pandas_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## pandas

# %%
import pandas as pd

# %% [markdown]
# ### DataFrame(데이터 프레임) = (Series + Series + Series + ...) + column
# * 다(복합) 변수

# %% [markdown]
# #### DataFrame 생성

# %%
list = [[3,4],[5,6],[7,8],[9,10]]
pd.DataFrame(list)
# Out:
#    0   1
# 0  3   4
# 1  5   6
# 2  7   8
# 3  9  10

# %%
pd.Series(list)
# Out:
# 0     [3, 4]
# 1     [5, 6]
# 2     [7, 8]
# 3    [9, 10]
# dtype: object

# %%
double_list = [
             [1000, '과자','2019-12-31','반품'],
             [2000, '음료', '2020-03-02','정상'],
             [3000, '아이스크림', '2020-02-03','정상'],
             [1000,'과자','2019-12-31','반품']
            ]

# %%
pd.DataFrame(double_list)
# Out:
#       0      1           2   3
# 0  1000     과자  2019-12-31  반품
# 1  2000     음료  2020-03-02  정상
# 2  3000  아이스크림  2020-02-03  정상
# 3  1000     과자  2019-12-31  반품

# %%
double_columns = ['가격','종류','판매일자','반품여부']
pd.DataFrame(data=double_list, columns=double_columns)
# Out:
#      가격     종류        판매일자 반품여부
# 0  1000     과자  2019-12-31   반품
# 1  2000     음료  2020-03-02   정상
# 2  3000  아이스크림  2020-02-03   정상
# 3  1000     과자  2019-12-31   반품

# %% [markdown]
# #### 내용 확인

# %%
df_saledays= pd.DataFrame(data=double_list, columns=double_columns)
type(df_saledays), df_saledays.shape
# Out:
# (pandas.core.frame.DataFrame, (4, 4))

# %%
df_saledays.index, df_saledays.columns, df_saledays.values
# Out:
# (RangeIndex(start=0, stop=4, step=1),
#  Index(['가격', '종류', '판매일자', '반품여부'], dtype='object'),
#  array([[1000, '과자', '2019-12-31', '반품'],
#         [2000, '음료', '2020-03-02', '정상'],
#         [3000, '아이스크림', '2020-02-03', '정상'],
#         [1000, '과자', '2019-12-31', '반품']], dtype=object))

# %% [markdown]
# #### 간편 확인

# %%
df_saledays[:2]
# Out:
#      가격  종류        판매일자 반품여부
# 0  1000  과자  2019-12-31   반품
# 1  2000  음료  2020-03-02   정상

# %%
df_saledays[:-1]
# Out:
#      가격     종류        판매일자 반품여부
# 0  1000     과자  2019-12-31   반품
# 1  2000     음료  2020-03-02   정상
# 2  3000  아이스크림  2020-02-03   정상

# %%
df_saledays.head(2)
# Out:
#      가격  종류        판매일자 반품여부
# 0  1000  과자  2019-12-31   반품
# 1  2000  음료  2020-03-02   정상

# %%
df_saledays[-2:]
# Out:
#      가격     종류        판매일자 반품여부
# 2  3000  아이스크림  2020-02-03   정상
# 3  1000     과자  2019-12-31   반품

# %% [markdown]
# #### 데이터 정보확인

# %%
df_saledays.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   가격      4 non-null      int64
#  1   종류      4 non-null      object
#  2   판매일자    4 non-null      object
#  3   반품여부    4 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 256.0+ bytes

# %%
df_saledays.describe()
# Out:
#                 가격
# count     4.000000
# mean   1750.000000
# std     957.427108
# min    1000.000000
# 25%    1000.000000
# 50%    1500.000000
# 75%    2250.000000
# max    3000.000000

# %%
df_saledays.columns
# Out:
# Index(['가격', '종류', '판매일자', '반품여부'], dtype='object')

# %%
df_saledays['종류']
# Out:
# 0       과자
# 1       음료
# 2    아이스크림
# 3       과자
# Name: 종류, dtype: object

# %%
df_saledays['종류'][1:3]
# Out:
# 1       음료
# 2    아이스크림
# Name: 종류, dtype: object

# %%
df_saledays['종류'].unique(), df_saledays['반품여부'].unique()
# Out:
# (array(['과자', '음료', '아이스크림'], dtype=object), array(['반품', '정상'], dtype=object))

# %% [markdown]
# ### 로딩 데이터셋

# %%
df_california_housing = pd.read_csv('sample_data/california_housing_test.csv')

# %%
pd.read_csv('sample_data/california_housing_test.csv')
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 0         1537.0       606.0         6.6085            344700.0
# 1          809.0       277.0         3.5990            176500.0
# 2         1484.0       495.0         5.7934            270500.0
# 3           49.0        11.0         6.1359            330000.0
# 4          850.0       237.0         2.9375             81700.0
# ...          ...         ...            ...                 ...
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
df_california_housing[100:150]
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 100    -118.30     34.02                49.0       2120.0           483.0
# 101    -122.23     37.79                43.0       5963.0          1344.0
# 102    -121.31     38.62                31.0       3114.0           430.0
# 103    -117.25     32.80                35.0       2281.0           506.0
# 104    -118.26     33.99                36.0       2016.0           505.0
# 105    -119.39     36.54                34.0       1590.0           422.0
# 106    -121.51     38.52                30.0       3236.0           588.0
# 107    -119.18     34.27                 6.0       2307.0           386.0
# 108    -118.18     33.77                30.0       1418.0           439.0
# 109    -122.43     37.74                52.0       1514.0           314.0
# 110    -117.93     33.91                24.0       1698.0           297.0
# 111    -124.16     40.77                35.0       2141.0           438.0
# 112    -117.95     33.63                27.0       2489.0           481.0
# 113    -118.05     34.10                36.0       1606.0           318.0
# 114    -116.97     32.81                19.0       1573.0           471.0
# 115    -118.85     34.17                42.0        564.0            96.0
# 116    -117.73     33.63                15.0       2874.0           592.0
# 117    -122.07     37.34                30.0       1851.0           238.0
# 118    -117.18     33.02                15.0       3540.0           453.0
# 119    -118.41     34.00                38.0        324.0            70.0
# 120    -121.96     37.30                20.0       4228.0          1006.0
# 121    -121.74     38.55                34.0       2299.0           579.0
# 122    -118.21     33.92                28.0       2949.0          1003.0
# 123    -121.90     36.61                29.0       3412.0           827.0
# 124    -117.81     33.84                17.0       4343.0           515.0
# 125    -118.19     33.93                42.0       1829.0           391.0
# 126    -120.93     37.73                14.0       2799.0           618.0
# 127    -122.02     37.96                25.0       2615.0           368.0
# 128    -122.47     37.79                52.0       2844.0           623.0
# 129    -117.19     34.03                25.0       2513.0           340.0
# 130    -117.24     32.80                28.0       1072.0           331.0
# 131    -118.13     34.10                19.0       2742.0           756.0
# 132    -122.42     37.73                50.0       3426.0           769.0
# 133    -118.14     34.71                32.0       1164.0           248.0
# 134    -119.76     36.75                39.0       2233.0           563.0
# 135    -122.34     37.56                39.0       3562.0           391.0
# 136    -122.45     40.46                16.0       2734.0           501.0
# 137    -118.29     33.91                31.0       2025.0           618.0
